# %%
import cv2 as computervision
import random
from google.colab.patches import cv2_imshow

# %%
image=computervision.imread("/content/image.jpg",1)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=420x510 at 0x7F6ED43CD490>

# %%
image_grey=computervision.imread("/content/image.jpg",0)
cv2_imshow(image_grey)
# Out:
# <PIL.Image.Image image mode=L size=420x510 at 0x7F6ED43BD250>

# %%
column=image.shape[1]
row=image.shape[0]
image=computervision.imread("/content/image.jpg",1)
for i in range(230,280):
  for j in range(120,300):
    image[i][j]=[random.randint(0,255),random.randint(0,255),random.randint(0,255)]
print("Row:",row)
print("Column:",column)
cv2_imshow(image)
# Out:
# Row: 510
# Column: 420
# <PIL.Image.Image image mode=RGB size=420x510 at 0x7F6ED43B4510>

# %%
image=computervision.imread("/content/image.jpg",1)
cut=image[100:150,200:250]
image[50:100,150:200]=cut
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=420x510 at 0x7F6ED43BD690>

# %%
computervision.rectangle(image,(0,0),(image.shape[1],image.shape[0]),(255,255,255),20)
cv2_imshow(image)
computervision.imwrite("Image with Frame.jpg",image)
# Out:
# <PIL.Image.Image image mode=RGB size=420x510 at 0x7F6ED43BD990>
# True

# %%
image.shape
# Out:
# (510, 420, 3)

# %%
cut=image[240:280,120:300]
image[40:80,120:300]=cut
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=420x510 at 0x7F6ED43D5950>

# %%
import numpy as np
import cv2 as cv2
camera=cv2.VideoCapture(0)
while True:
  ret,frame= camera.read()
  cv2.imwrite("test.jpg",frame)
  result=False
camera.release()
camera.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-11-2d3c4c46f11e> in <module>()
#       4 while True:
#       5   ret,frame= camera.read()
# ----> 6   cv2.imwrite("test.jpg",frame)
#       7   result=False
#       8 camera.release()
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgcodecs/src/loadsave.cpp:715: error: (-215:Assertion failed) !_img.empty() in function 'imwrite'
